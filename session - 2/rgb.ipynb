# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("RGB_Matte.png")

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x7FABFE7B9410>

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (480, 640, 3)

# %%
red = arr[100:200, :300]

# %%
plt.imshow(red)
