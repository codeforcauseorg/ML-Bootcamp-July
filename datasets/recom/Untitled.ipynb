# %%
import pandas as pd

# %%
data = pd.read_csv("rating.csv")

# %%
from sklearn.model_selection import train_test_split

# %%
out = train_test_split(data, test_size=0.5)

# %%
out[0].to_csv("rating.csv")
